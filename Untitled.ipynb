# %%
# !pip install folium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 kB 1.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
import hvplot.pandas
import requests
import csv
import json
import pathlib as Path
import folium

# %%
url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"city":"Sacramento","state":"CA","limit":"250"}

headers = {
	"X-RapidAPI-Key": "ed559ee283msh649d2a47430748cp19d57ajsn27b169833529",
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# [{"price":298000,"county":"Sacramento","propertyType":"Land","addressLine1":"40 South Ave","city":"Sacramento","state":"CA","zipCode":"95838","formattedAddress":"40 South Ave, Sacramento, CA 95838","lastSeen":"2023-02-02T00:00:00.000Z","listedDate":"2022-12-30T00:00:00.000Z","status":"Active","removedDate":null,"daysOnMarket":34,"createdDate":"2020-09-15T19:10:22.826Z","lotSize":62291,"id":"40-South-Ave,-Sacramento,-CA-95838","latitude":38.632503,"longitude":-121.468643},{"price":325000,"county":"Sacramento","propertyType":"Land","addressLine1":"3241 W St","city":"Sacramento","state":"CA","zipCode":"95817","formattedAddress":"3241 W St, Sacramento, CA 95817","lastSeen":"2023-02-02T00:00:00.000Z","listedDate":"2022-12-23T00:00:00.000Z","status":"Active","removedDate":null,"daysOnMarket":41,"createdDate":"2020-09-15T20:22:21.612Z","lotSize":3206,"id":"3241-W-St,-Sacramento,-CA-95817","latitude":38.557692,"longitude":-121.469317},{"price":325000,"county":"Sacramento","propertyType":"Lan
# ...

# %%
Sac_df = pd.DataFrame(json.loads(response.text))

# %%
Sac_df
# Out:
#       price      county   propertyType          addressLine1        city  \
# 0    298000  Sacramento           Land          40 South Ave  Sacramento
# 1    325000  Sacramento           Land             3241 W St  Sacramento
# 2    325000  Sacramento           Land             3255 W St  Sacramento
# 3    249900  Sacramento           Land        605 Claire Ave  Sacramento
# 4    380000  Sacramento  Single Family      3815 Annadale Ln  Sacramento
# ..      ...         ...            ...                   ...         ...
# 245  589900  Sacramento  Single Family  6002 Windbreaker Way  Sacramento
# 246   95000  Sacramento   Manufactured       193 Village Cir  Sacramento
# 247  360000  Sacramento  Single Family      2796-0 Branch St  Sacramento
# 248  170000  Sacramento          Condo        41 La Fresa Ct  Sacramento
# 249  398000  Sacramento  Single Family      7833 Shrader Cir  Sacramento
#
#     state zipCode                             formattedAddress  \
# ...

# %%
Sac_map = folium.Map(location=[Sac_df["latitude"].mean(), Sac_df["longitude"].mean()], zoom_start=12)

# %%
for i, row in Sac_df.iterrows():
    folium.Marker(
        location=[row["latitude"], row["longitude"]],
        popup=f"{row['formattedAddress']}<br>Price: ${row['price']}",
    ).add_to(Sac_map)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save("real_estate_map.html")
